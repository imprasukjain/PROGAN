# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import (Reshape,LeakyReLU,Dropout,Conv2DTranspose, Add,AveragePooling2D,Lambda,
                                     UpSampling2D, Conv2D, MaxPool2D, Dense,Activation,
                                     Flatten, InputLayer, BatchNormalization, Input, )
from tensorflow.keras.optimizers import Adam

# %%
NOISE_DIM = 512
BATCH_SIZE = [16, 16, 16, 16, 16, 16,]
EPOCHS = 50

# %%
def preprocess(image):
    
    return tf.cast(image, tf.float32) / 127.5 - 1.0

# %%
def create_dataset(res,BATCH_SIZE):
  ds_train = tf.keras.preprocessing.image_dataset_from_directory(
      "/kaggle/input/celebahq-resized-256x256/celeba_hq_256", label_mode=None, image_size=(res,res), batch_size=BATCH_SIZE
  )
  
  train_dataset = (
      ds_train
      .map(preprocess)
      .unbatch()
      .shuffle(buffer_size = 1024, reshuffle_each_iteration = True)
      .batch(BATCH_SIZE,drop_remainder=True)
      .prefetch(tf.data.AUTOTUNE)
  )
  return train_dataset
train_dataset = create_dataset(4,BATCH_SIZE[0])
# Out:
# Found 30000 files belonging to 1 classes.

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=TensorSpec(shape=(16, 4, 4, 3), dtype=tf.float32, name=None)>

# %%
for d in create_dataset(256,32).take(1):
  print(d.shape)
# Out:
# Found 30000 files belonging to 1 classes.
# (32, 256, 256, 3)

# %%
plt.figure(figsize = (16,16))
k=0
n = 16
for i in range(n):
    ax = plt.subplot(4,4, k+1)
    plt.imshow((d[i]+1)/2)
    plt.axis("off")
    k+=1

# %%
class PixelNormalization(Layer):
    def __init__(self,):
        super(PixelNormalization, self).__init__()
    
    def call(self, inputs):
        mean_square = tf.reduce_mean(tf.square(inputs), axis=-1, keepdims=True)
        l2 = tf.math.rsqrt(mean_square + 1.0e-8)
        normalized = inputs * l2
        
        

        return normalized

# %%
class WeightScaling(Layer):
    def __init__(self, shape, gain = np.sqrt(2),):
        super(WeightScaling, self).__init__()
      #shape = tf.constant(shape, dtype=tf.float32)
        fan_in = tf.math.reduce_prod(shape)
        self.wscale = gain*tf.math.rsqrt(fan_in)
      
    def call(self, inputs):
        inputs = tf.cast(inputs, tf.float32)
        return inputs * self.wscale

# %%
class Bias(Layer):
    def __init__(self, ):
        super(Bias, self).__init__()

    def build(self, input_shape):
        b_init = tf.zeros_initializer()
        self.bias = tf.Variable(
            initial_value = b_init(shape=(input_shape[-1],), dtype='float32'),
            trainable=True)  

    def call(self, inputs,):
        return inputs + self.bias

# %%
class WeightScalingDense(Layer):
    def __init__(self, n_units,gain,use_pixelnorm=False,activate=None):
        super(WeightScalingDense, self).__init__()
        self.n_units=n_units
        self.gain=gain
        self.use_pixelnorm=use_pixelnorm
        self.activate=activate
    def build(self,input_shape):

        self.dense=Dense(
            self.n_units,
            use_bias=False,
            kernel_initializer=tf.keras.initializers.RandomNormal(mean=0., stddev=1.),
            dtype='float32')
        self.bias=Bias()


    def call(self,inputs):
        in_filters = tf.shape(inputs)[-1]

        x=self.dense(inputs)

        x=WeightScaling(shape=(tf.cast(in_filters,dtype=tf.float32)), gain=self.gain)(x)
        x=self.bias(x)

        if self.activate=='LeakyReLU':
            x=LeakyReLU(0.2)(x)
        elif self.activate=='tanh':
            x=Activation('tanh')(x)
      
        if self.use_pixelnorm:
            x=PixelNormalization()(x)
        return x

# %%
class WeightScalingConv(Layer):
    def __init__(self, n_filters,kernel_size,gain,use_pixelnorm=False,activate=None, strides=(1,1)):
        
        
        super(WeightScalingConv, self).__init__()
        self.n_filters=n_filters
        self.gain=gain
        self.kernel_size=kernel_size
        self.use_pixelnorm=use_pixelnorm
        self.activate=activate
        self.strides=strides
    def build(self,input_shape):
        
        self.conv=Conv2D(
          self.n_filters,
          self.kernel_size,
          strides=self.strides,
          use_bias=False,
          padding="same",
          kernel_initializer=tf.keras.initializers.RandomNormal(mean=0., stddev=1.),
          dtype='float32')
        self.bias=Bias()
      
    def call(self,inputs):
        in_filters = tf.shape(inputs)[-1]

        x=self.conv(inputs)
        x=WeightScaling(shape=(tf.cast(self.kernel_size[0],dtype=tf.float32),tf.cast(self.kernel_size[1],dtype=tf.float32),tf.cast(in_filters,dtype=tf.float32)), gain=self.gain)(x)
        x=self.bias(x)
      
        if self.activate=='LeakyReLU':
            x=LeakyReLU(0.2)(x)
        elif self.activate=='tanh':
            x=Activation('tanh')(x)
      
        if self.use_pixelnorm:
            x = PixelNormalization()(x)
        return x

# %%
class MinibatchStdev(Layer):
    def __init__(self, **kwargs):
        super(MinibatchStdev, self).__init__(**kwargs)
    
    def call(self, inputs):
        mean = tf.reduce_mean(inputs, axis=0, keepdims=True)
        stddev = tf.sqrt(tf.reduce_mean(tf.square(inputs - mean), axis=0, keepdims=True) + 1e-8)
        average_stddev = tf.reduce_mean(stddev, keepdims=True)
        shape = tf.shape(inputs)
        minibatch_stddev = tf.tile(average_stddev, (shape[0], shape[1], shape[2], 1))
        combined = tf.concat([inputs, minibatch_stddev], axis=-1)
      
        return combined

# %%
FILTERS = [512, 512, 512, 512, 256, 128, 64]

# %%
class WeightedSum(Layer):
    def __init__(self,):
        super(WeightedSum, self).__init__()
    def build(self,input_shape):
        self.alpha = tf.Variable(0., dtype=tf.float32, trainable=False)
    def call(self,inputs):
        return ((1.0 - self.alpha) * inputs[0] + (self.alpha * inputs[1]))

# %%
class ProGAN(Model):
    def __init__(self,latent_dim,d_steps=1,gp_weight=10.0,drift_weight=0.001,):
        super(ProGAN, self).__init__()
        self.latent_dim = latent_dim
        self.d_steps = d_steps
        self.gp_weight = gp_weight
        self.drift_weight = drift_weight
        self.n_depth = 0
        self.discriminator = self.init_discriminator()
        self.discriminator_wt_fade = None
        self.generator = self.init_generator()
        self.generator_wt_fade = None

    def init_discriminator(self):
        img_input = Input(shape = (4,4,3))
        img_input = tf.cast(img_input, tf.float32)
      
      # fromRGB
        x=WeightScalingConv(n_filters=FILTERS[0],kernel_size=(1,1),gain=np.sqrt(2),activate='LeakyReLU')(img_input)
      
        x = MinibatchStdev()(x)

        x=WeightScalingConv(n_filters=FILTERS[0],kernel_size=(3,3),gain=np.sqrt(2),activate='LeakyReLU')(x)
        x=WeightScalingConv(n_filters=FILTERS[0],kernel_size=(4,4),gain=np.sqrt(2),activate='LeakyReLU', strides=(4,4))(x)
      
        x = Flatten()(x)
      
        x= WeightScalingDense(n_units=1,gain=1.)(x)

        d_model = Model(img_input, x, name='discriminator')

        return d_model

    def fade_in_discriminator(self):
        input_shape = list(self.discriminator.input.shape)
      
        input_shape = (input_shape[1]*2, input_shape[2]*2, input_shape[3])
        img_input = Input(shape = input_shape)
        img_input = tf.cast(img_input, tf.float32)
      ################## Left
        x1 = AveragePooling2D()(img_input)
        x1 = self.discriminator.layers[1](x1)

        x2=WeightScalingConv(FILTERS[self.n_depth],(1,1),np.sqrt(2),activate='LeakyReLU')(img_input)      
        x2=WeightScalingConv(FILTERS[self.n_depth],(3,3),np.sqrt(2), activate='LeakyReLU')(x2)
        x2=WeightScalingConv(FILTERS[self.n_depth-1],(3,3),np.sqrt(2), activate='LeakyReLU')(x2)

        x2 = AveragePooling2D()(x2)
 
        x = WeightedSum()([x1, x2])

        for i in range(2, len(self.discriminator.layers)):
            x2 = self.discriminator.layers[i](x2)
        self.discriminator_stabilize = Model(img_input, x2, name='discriminator')

        for i in range(2, len(self.discriminator.layers)):
            x = self.discriminator.layers[i](x)
        self.discriminator = Model(img_input, x, name='discriminator')
        self.discriminator.summary()

    def stabilize_discriminator(self):
        self.discriminator = self.discriminator_stabilize
        self.discriminator.summary()

    def init_generator(self):
        noise = Input(shape=(self.latent_dim,))
        x = PixelNormalization()(noise)      
        x=WeightScalingDense(n_units=4*4*FILTERS[0], gain=np.sqrt(2)/4, activate='LeakyReLU', use_pixelnorm=True)(x)

        x = Reshape((4, 4, FILTERS[0]))(x)

        x=WeightScalingConv(FILTERS[0], kernel_size=(4,4), gain=np.sqrt(2), activate='LeakyReLU', use_pixelnorm=True)(x)
        x=WeightScalingConv(FILTERS[0], kernel_size=(3,3), gain=np.sqrt(2), activate='LeakyReLU', use_pixelnorm=True)(x)
        x=WeightScalingConv(3, kernel_size=(1,1), gain=1., activate='tanh', use_pixelnorm=False)(x)
      
        g_model = Model(noise, x, name='generator')
        g_model.summary()
        return g_model

    def fade_in_generator(self):
        block_end = self.generator.layers[-2].output
        block_end = UpSampling2D((2,2))(block_end)
 
        x1 = self.generator.layers[-1](block_end)

        x2=WeightScalingConv(FILTERS[self.n_depth],(3,3),np.sqrt(2),
                           activate='LeakyReLU',use_pixelnorm=True)(block_end)
        x2=WeightScalingConv(FILTERS[self.n_depth],(3,3),np.sqrt(2),
                           activate='LeakyReLU',use_pixelnorm=True)(x2)      
        x2=WeightScalingConv(3,(1,1),1.,activate='tanh',use_pixelnorm=False)(x2)

        self.generator_stabilize = Model(self.generator.input, x2, name='generator')

        x = WeightedSum()([x1, x2])
        self.generator = Model(self.generator.input, x, name='generator')

        self.generator.summary()

    def stabilize_generator(self):
        self.generator = self.generator_stabilize
        self.generator.summary()

    def compile(self, d_optimizer, g_optimizer):
        super(ProGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer

    def gradient_penalty(self,batch_size,real_images,fake_images):
        
        epsilon=tf.random.normal([batch_size,1,1,1],0.0,1.0)
        interpolation=epsilon*real_images+(1-epsilon)*fake_images

        with tf.GradientTape() as gp_tape:
            
            gp_tape.watch(interpolation)
            prediction=self.discriminator(interpolation,training=True)
        grads=gp_tape.gradient(prediction,interpolation)
        l2_norm=tf.sqrt(tf.reduce_sum(tf.square(grads),axis=[1,2,3]))
        return tf.reduce_mean((l2_norm-1)**2)
    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        batch_size = tf.shape(real_images)[0]
        
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_logits = self.discriminator(fake_images, training=True)
            real_logits = self.discriminator(real_images, training=True)

            d_cost = tf.reduce_mean(fake_logits) - tf.reduce_mean(real_logits)

            gp = self.gradient_penalty(batch_size, real_images, fake_images)

            drift = tf.reduce_mean(tf.square(real_logits))
            d_loss = d_cost + self.gp_weight * gp + self.drift_weight * drift

        d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
        self.d_optimizer.apply_gradients(zip(d_gradient, self.discriminator.trainable_variables))

        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            generated_images = self.generator(random_latent_vectors, training=True)
            gen_img_logits = self.discriminator(generated_images, training=True)
            g_loss = -tf.reduce_mean(gen_img_logits)
        g_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(g_gradient, self.generator.trainable_variables))
        return {'d_loss': d_loss, 'g_loss': g_loss}

# %%
class ShowImage(tf.keras.callbacks.Callback):
    def __init__(self,prefix,res,latent_dim=512,steps_per_epoch=1000,epochs=50,):
        self.latent_dim = latent_dim
        self.prefix=prefix
        self.steps_per_epoch=steps_per_epoch
        self.epochs=epochs
        self.res=res

    def on_epoch_begin(self, epoch, logs=None):
        self.n_epoch = epoch

    def on_epoch_end(self, epoch, logs=None):
        n=6
        k=0
        out=self.model.generator(tf.random.normal(shape=(36, self.latent_dim)))
        plt.figure(figsize=(16,16))
        for i in range(n):
            for j in range(n):
                
                ax=plt.subplot(n,n,k+1)
                plt.imshow((out[k]+1)/2,)
                plt.axis('off')
                k+=1
        plt.savefig("generated/gen_images_{}x{}_{}_epoch_{}.png".format(self.res,self.res,self.prefix,epoch+1))

    def on_batch_begin(self, batch, logs=None):
        alpha = ((self.n_epoch * self.steps_per_epoch) + batch)/float(self.steps_per_epoch * self.epochs - 1)
        for layer in self.model.generator.layers:
            if isinstance(layer, WeightedSum):
                layer.alpha.assign(alpha)
        for layer in self.model.discriminator.layers:
            if isinstance(layer, WeightedSum):
                layer.alpha.assign(alpha)

# %%
# !mkdir generated

# %%
STEPS_PER_EPOCH=1000
EPOCHS=50
NOISE_DIM=512

# %%
train_dataset = create_dataset(4,BATCH_SIZE[0])
generator_optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.0, beta_2=0.99, epsilon=1e-8)
discriminator_optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.0, beta_2=0.99, epsilon=1e-8)

pgan = ProGAN(
    latent_dim = NOISE_DIM, 
    d_steps = 1,
)

pgan.compile(
    d_optimizer=discriminator_optimizer,
    g_optimizer=generator_optimizer,
)

cbk=ShowImage('initial',4,latent_dim=512,steps_per_epoch=STEPS_PER_EPOCH,epochs=EPOCHS)
pgan.fit(train_dataset.take(STEPS_PER_EPOCH),epochs = EPOCHS, callbacks=[cbk])
# Out:
# Found 30000 files belonging to 1 classes.
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 512)]             0
#
#  pixel_normalization_152 (Pi  (None, 512)              0
#  xelNormalization)
#
#  weight_scaling_dense_5 (Wei  (None, 8192)             4202496
#  ghtScalingDense)
#
#  reshape_2 (Reshape)         (None, 4, 4, 512)         0
#
#  weight_scaling_conv_21 (Wei  (None, 4, 4, 512)        4194816
#  ghtScalingConv)
#
#  weight_scaling_conv_22 (Wei  (None, 4, 4, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_23 (Wei  (None, 4, 4, 3)          1539
#  ghtScalingConv)
#
# =================================================================
# Total params: 10,758,659
# Trainable params: 10,758,659
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 47s 41ms/step - d_loss: -0.4631 - g_loss: 0.7031
# Epoch 2/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0841 - g_loss: 0.3444
# Epoch 3/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: -0.1295 - g_loss: 0.3711
# Epoch 4/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.1635 - g_loss: 0.4016
# Epoch 5/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.1765 - g_loss: 0.4016
# Epoch 6/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.1626 - g_loss: 0.3870
# Epoch 7/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.1437 - g_loss: 0.3542
# Epoch 8/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.1073 - g_loss: 0.3231
# Epoch 9/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0814 - g_loss: 0.3172
# Epoch 10/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0789 - g_loss: 0.3098
# Epoch 11/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0879 - g_loss: 0.2771
# Epoch 12/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0976 - g_loss: 0.2509
# Epoch 13/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0905 - g_loss: 0.2416
# Epoch 14/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0846 - g_loss: 0.2357
# Epoch 15/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0739 - g_loss: 0.2107
# Epoch 16/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0558 - g_loss: 0.2065
# Epoch 17/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0401 - g_loss: 0.1706
# Epoch 18/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0322 - g_loss: 0.1590
# Epoch 19/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: -0.0211 - g_loss: 0.1703
# Epoch 20/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: -0.0049 - g_loss: 0.1458
# Epoch 21/50
#  999/1000 [============================>.] - ETA: 0s - d_loss: 0.0012 - g_loss: 0.1156
# /tmp/ipykernel_28/1660940189.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(16,16))
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0015 - g_loss: 0.1160
# Epoch 22/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0105 - g_loss: 0.1461
# Epoch 23/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0147 - g_loss: 0.1126
# Epoch 24/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0125 - g_loss: 0.1182
# Epoch 25/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0196 - g_loss: 0.1282
# Epoch 26/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: 0.0191 - g_loss: 0.1149
# Epoch 27/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0134 - g_loss: 0.0921
# Epoch 28/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0193 - g_loss: 0.1206
# Epoch 29/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0145 - g_loss: 0.1255
# Epoch 30/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0215 - g_loss: 0.0792
# Epoch 31/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0169 - g_loss: 0.0755
# Epoch 32/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0205 - g_loss: 0.0966
# Epoch 33/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0203 - g_loss: 0.0868
# Epoch 34/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0173 - g_loss: 0.0949
# Epoch 35/50
# 1000/1000 [==============================] - 33s 33ms/step - d_loss: 0.0128 - g_loss: 0.0848
# Epoch 36/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: 0.0165 - g_loss: 0.0777
# Epoch 37/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0156 - g_loss: 0.0691
# Epoch 38/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0116 - g_loss: 0.0738
# Epoch 39/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0091 - g_loss: 0.0720
# Epoch 40/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0072 - g_loss: 0.0572
# Epoch 41/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0068 - g_loss: 0.0587
# Epoch 42/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0040 - g_loss: 0.0773
# Epoch 43/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0093 - g_loss: 0.0586
# Epoch 44/50
# 1000/1000 [==============================] - 33s 32ms/step - d_loss: 0.0085 - g_loss: 0.0549
# Epoch 45/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: 8.4463e-04 - g_loss: 0.0688
# Epoch 46/50
# 1000/1000 [==============================] - 32s 32ms/step - d_loss: 0.0045 - g_loss: 0.0626
# Epoch 47/50
# 1000/1000 [==============================] - 33s 33ms/step - d_loss: 0.0072 - g_loss: 0.0508
# Epoch 48/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0025 - g_loss: 0.0618
# Epoch 49/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0046 - g_loss: 0.0672
# Epoch 50/50
# 1000/1000 [==============================] - 32s 31ms/step - d_loss: 0.0049 - g_loss: 0.0503

# %%
for n_depth in range(1, 6):
    

  ################ Faded
    pgan.n_depth = n_depth
    train_dataset=create_dataset(4*(2**n_depth),BATCH_SIZE[n_depth])

    cbk=ShowImage('fading',4*(2**n_depth),latent_dim=512,steps_per_epoch=STEPS_PER_EPOCH,epochs=EPOCHS)
    pgan.fade_in_generator()
    pgan.fade_in_discriminator()

    pgan.compile(
      d_optimizer=discriminator_optimizer,
      g_optimizer=generator_optimizer,
    )
  
    pgan.fit(train_dataset.take(STEPS_PER_EPOCH),epochs = EPOCHS, callbacks=[cbk])
  
  ################# Stabilized

    cbk=ShowImage('stabilize',4*(2**n_depth),latent_dim=512,steps_per_epoch=STEPS_PER_EPOCH,epochs=EPOCHS)
    pgan.stabilize_generator()
    pgan.stabilize_discriminator()

    pgan.compile(
      d_optimizer=discriminator_optimizer,
      g_optimizer=generator_optimizer,
    )
    pgan.fit(train_dataset.take(STEPS_PER_EPOCH),epochs=EPOCHS, callbacks=[cbk])
# Out:
# Found 30000 files belonging to 1 classes.
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 512)]        0           []
#
#  pixel_normalization_152 (Pixel  (None, 512)         0           ['input_12[0][0]']
#  Normalization)
#
#  weight_scaling_dense_5 (Weight  (None, 8192)        4202496     ['pixel_normalization_152[0][0]']
#  ScalingDense)
#
#  reshape_2 (Reshape)            (None, 4, 4, 512)    0           ['weight_scaling_dense_5[0][0]']
#
#  weight_scaling_conv_21 (Weight  (None, 4, 4, 512)   4194816     ['reshape_2[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_22 (Weight  (None, 4, 4, 512)   2359808     ['weight_scaling_conv_21[0][0]']
#  ScalingConv)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 512)   0           ['weight_scaling_conv_22[0][0]']
#
#  weight_scaling_conv_24 (Weight  (None, 8, 8, 512)   2359808     ['up_sampling2d_1[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_25 (Weight  (None, 8, 8, 512)   2359808     ['weight_scaling_conv_24[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_23 (Weight  multiple            1539        ['up_sampling2d_1[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_26 (Weight  (None, 8, 8, 3)     1539        ['weight_scaling_conv_25[0][0]']
#  ScalingConv)
#
#  weighted_sum_2 (WeightedSum)   (None, 8, 8, 3)      1           ['weight_scaling_conv_23[1][0]',
#                                                                   'weight_scaling_conv_26[0][0]']
#
# ==================================================================================================
# Total params: 15,479,815
# Trainable params: 15,479,814
# Non-trainable params: 1
# __________________________________________________________________________________________________
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 8, 8, 3)]    0           []
#
#  weight_scaling_conv_27 (Weight  (None, 8, 8, 512)   2048        ['input_15[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_28 (Weight  (None, 8, 8, 512)   2359808     ['weight_scaling_conv_27[2][0]']
#  ScalingConv)
#
#  average_pooling2d_2 (AveragePo  (None, 4, 4, 3)     0           ['input_15[0][0]']
#  oling2D)
#
#  weight_scaling_conv_29 (Weight  (None, 8, 8, 512)   2359808     ['weight_scaling_conv_28[2][0]']
#  ScalingConv)
#
#  weight_scaling_conv_18 (Weight  (None, 4, 4, 512)   2048        ['average_pooling2d_2[1][0]']
#  ScalingConv)
#
#  average_pooling2d_3 (AveragePo  (None, 4, 4, 512)   0           ['weight_scaling_conv_29[2][0]']
#  oling2D)
#
#  weighted_sum_3 (WeightedSum)   (None, 4, 4, 512)    1           ['weight_scaling_conv_18[3][0]',
#                                                                   'average_pooling2d_3[2][0]']
#
#  minibatch_stdev_2 (MinibatchSt  (None, 4, 4, 513)   0           ['weighted_sum_3[1][0]']
#  dev)
#
#  weight_scaling_conv_19 (Weight  (None, 4, 4, 512)   2364416     ['minibatch_stdev_2[5][0]']
#  ScalingConv)
#
#  weight_scaling_conv_20 (Weight  (None, 1, 1, 512)   4194816     ['weight_scaling_conv_19[5][0]']
#  ScalingConv)
#
#  flatten_2 (Flatten)            (None, 512)          0           ['weight_scaling_conv_20[5][0]']
#
#  weight_scaling_dense_4 (Weight  (None, 1)           513         ['flatten_2[5][0]']
#  ScalingDense)
#
# ==================================================================================================
# Total params: 11,283,458
# Trainable params: 11,283,457
# Non-trainable params: 1
# __________________________________________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 62s 56ms/step - d_loss: -1.8393 - g_loss: 2.8796
# Epoch 2/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.2936 - g_loss: 3.7070
# Epoch 3/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.3724 - g_loss: 4.1425
# Epoch 4/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.3995 - g_loss: 4.0875
# Epoch 5/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.4386 - g_loss: 4.1101
# Epoch 6/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.3315 - g_loss: 4.1477
# Epoch 7/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.1748 - g_loss: 3.9992
# Epoch 8/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -3.0704 - g_loss: 3.8614
# Epoch 9/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -2.8237 - g_loss: 3.5678
# Epoch 10/50
# 1000/1000 [==============================] - 61s 60ms/step - d_loss: -2.6286 - g_loss: 3.3315
# Epoch 11/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -2.4051 - g_loss: 3.0722
# Epoch 12/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -2.2113 - g_loss: 2.8589
# Epoch 13/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -2.0725 - g_loss: 2.6656
# Epoch 14/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -1.8796 - g_loss: 2.4168
# Epoch 15/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -1.7508 - g_loss: 2.2977
# Epoch 16/50
# 1000/1000 [==============================] - 58s 57ms/step - d_loss: -1.6333 - g_loss: 2.1210
# Epoch 17/50
# 1000/1000 [==============================] - 58s 57ms/step - d_loss: -1.4954 - g_loss: 1.9503
# Epoch 18/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -1.4033 - g_loss: 1.8188
# Epoch 19/50
# 1000/1000 [==============================] - 57s 57ms/step - d_loss: -1.2640 - g_loss: 1.6559
# Epoch 20/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -1.1630 - g_loss: 1.5791
# Epoch 21/50
# 1000/1000 [==============================] - ETA: 0s - d_loss: -1.0010 - g_loss: 1.3741
# /tmp/ipykernel_28/1660940189.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(16,16))
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -1.0008 - g_loss: 1.3738
# Epoch 22/50
# 1000/1000 [==============================] - 58s 57ms/step - d_loss: -0.8674 - g_loss: 1.2390
# Epoch 23/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.7323 - g_loss: 1.0715
# Epoch 24/50
# 1000/1000 [==============================] - 57s 57ms/step - d_loss: -0.6436 - g_loss: 0.9317
# Epoch 25/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.5346 - g_loss: 0.8182
# Epoch 26/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.4491 - g_loss: 0.7430
# Epoch 27/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.3761 - g_loss: 0.6379
# Epoch 28/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.3011 - g_loss: 0.5617
# Epoch 29/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.2399 - g_loss: 0.4669
# Epoch 30/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.1803 - g_loss: 0.4104
# Epoch 31/50
# 1000/1000 [==============================] - 58s 57ms/step - d_loss: -0.1305 - g_loss: 0.3583
# Epoch 32/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0734 - g_loss: 0.2542
# Epoch 33/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0383 - g_loss: 0.2373
# Epoch 34/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0188 - g_loss: 0.1728
# Epoch 35/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0031 - g_loss: 0.1648
# Epoch 36/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: 0.0034 - g_loss: 0.1499
# Epoch 37/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: 0.0318 - g_loss: 0.0978
# Epoch 38/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: 0.0365 - g_loss: 0.1074
# Epoch 39/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: 0.0385 - g_loss: 0.0842
# Epoch 40/50
# 1000/1000 [==============================] - 56s 56ms/step - d_loss: 0.0477 - g_loss: 0.1022
# Epoch 41/50
# 1000/1000 [==============================] - 58s 57ms/step - d_loss: 0.0136 - g_loss: 0.1380
# Epoch 42/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: 0.0025 - g_loss: 0.1239
# Epoch 43/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0214 - g_loss: 0.1322
# Epoch 44/50
# 1000/1000 [==============================] - 56s 56ms/step - d_loss: -0.0331 - g_loss: 0.1514
# Epoch 45/50
# 1000/1000 [==============================] - 56s 56ms/step - d_loss: -0.0391 - g_loss: 0.1722
# Epoch 46/50
# 1000/1000 [==============================] - 56s 56ms/step - d_loss: -0.0571 - g_loss: 0.1944
# Epoch 47/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0704 - g_loss: 0.2328
# Epoch 48/50
# 1000/1000 [==============================] - 56s 56ms/step - d_loss: -0.0679 - g_loss: 0.2532
# Epoch 49/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.0795 - g_loss: 0.2349
# Epoch 50/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.1004 - g_loss: 0.2140
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 512)]             0
#
#  pixel_normalization_152 (Pi  (None, 512)              0
#  xelNormalization)
#
#  weight_scaling_dense_5 (Wei  (None, 8192)             4202496
#  ghtScalingDense)
#
#  reshape_2 (Reshape)         (None, 4, 4, 512)         0
#
#  weight_scaling_conv_21 (Wei  (None, 4, 4, 512)        4194816
#  ghtScalingConv)
#
#  weight_scaling_conv_22 (Wei  (None, 4, 4, 512)        2359808
#  ghtScalingConv)
#
#  up_sampling2d_1 (UpSampling  (None, 8, 8, 512)        0
#  2D)
#
#  weight_scaling_conv_24 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_25 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_26 (Wei  (None, 8, 8, 3)          1539
#  ghtScalingConv)
#
# =================================================================
# Total params: 15,478,275
# Trainable params: 15,478,275
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 8, 8, 3)]         0
#
#  weight_scaling_conv_27 (Wei  (None, 8, 8, 512)        2048
#  ghtScalingConv)
#
#  weight_scaling_conv_28 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_29 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  average_pooling2d_3 (Averag  (None, 4, 4, 512)        0
#  ePooling2D)
#
#  minibatch_stdev_2 (Minibatc  (None, 4, 4, 513)        0
#  hStdev)
#
#  weight_scaling_conv_19 (Wei  (None, 4, 4, 512)        2364416
#  ghtScalingConv)
#
#  weight_scaling_conv_20 (Wei  (None, 1, 1, 512)        4194816
#  ghtScalingConv)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  weight_scaling_dense_4 (Wei  (None, 1)                513
#  ghtScalingDense)
#
# =================================================================
# Total params: 11,281,409
# Trainable params: 11,281,409
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 57s 54ms/step - d_loss: -0.1039 - g_loss: 0.2975
# Epoch 2/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1197 - g_loss: 0.2631
# Epoch 3/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1155 - g_loss: 0.2162
# Epoch 4/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.1228 - g_loss: 0.2979
# Epoch 5/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1204 - g_loss: 0.2468
# Epoch 6/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1253 - g_loss: 0.3006
# Epoch 7/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1295 - g_loss: 0.2896
# Epoch 8/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1274 - g_loss: 0.3047
# Epoch 9/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1376 - g_loss: 0.2668
# Epoch 10/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1351 - g_loss: 0.2571
# Epoch 11/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1391 - g_loss: 0.2269
# Epoch 12/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1253 - g_loss: 0.2393
# Epoch 13/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1315 - g_loss: 0.2684
# Epoch 14/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1278 - g_loss: 0.2879
# Epoch 15/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1451 - g_loss: 0.2652
# Epoch 16/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1397 - g_loss: 0.2417
# Epoch 17/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1428 - g_loss: 0.2791
# Epoch 18/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1483 - g_loss: 0.2573
# Epoch 19/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1446 - g_loss: 0.2958
# Epoch 20/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.1465 - g_loss: 0.2056
# Epoch 21/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1508 - g_loss: 0.2793
# Epoch 22/50
# 1000/1000 [==============================] - 54s 54ms/step - d_loss: -0.1395 - g_loss: 0.2741
# Epoch 23/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1413 - g_loss: 0.2448
# Epoch 24/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1479 - g_loss: 0.2668
# Epoch 25/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1480 - g_loss: 0.2906
# Epoch 26/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1604 - g_loss: 0.2111
# Epoch 27/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1535 - g_loss: 0.2938
# Epoch 28/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1531 - g_loss: 0.3108
# Epoch 29/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1526 - g_loss: 0.2798
# Epoch 30/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1504 - g_loss: 0.2610
# Epoch 31/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1628 - g_loss: 0.2976
# Epoch 32/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1655 - g_loss: 0.2752
# Epoch 33/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1563 - g_loss: 0.2317
# Epoch 34/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1652 - g_loss: 0.3427
# Epoch 35/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1664 - g_loss: 0.2638
# Epoch 36/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1733 - g_loss: 0.2701
# Epoch 37/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1613 - g_loss: 0.3020
# Epoch 38/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1714 - g_loss: 0.2873
# Epoch 39/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1690 - g_loss: 0.2308
# Epoch 40/50
# 1000/1000 [==============================] - 57s 56ms/step - d_loss: -0.1682 - g_loss: 0.3113
# Epoch 41/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1581 - g_loss: 0.3071
# Epoch 42/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1632 - g_loss: 0.2646
# Epoch 43/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1818 - g_loss: 0.2774
# Epoch 44/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1782 - g_loss: 0.2920
# Epoch 45/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1650 - g_loss: 0.2476
# Epoch 46/50
# 1000/1000 [==============================] - 54s 54ms/step - d_loss: -0.1721 - g_loss: 0.2763
# Epoch 47/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1708 - g_loss: 0.3187
# Epoch 48/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1739 - g_loss: 0.2622
# Epoch 49/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1691 - g_loss: 0.2494
# Epoch 50/50
# 1000/1000 [==============================] - 55s 54ms/step - d_loss: -0.1761 - g_loss: 0.3270
# Found 30000 files belonging to 1 classes.
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 512)]        0           []
#
#  pixel_normalization_152 (Pixel  (None, 512)         0           ['input_12[0][0]']
#  Normalization)
#
#  weight_scaling_dense_5 (Weight  (None, 8192)        4202496     ['pixel_normalization_152[0][0]']
#  ScalingDense)
#
#  reshape_2 (Reshape)            (None, 4, 4, 512)    0           ['weight_scaling_dense_5[0][0]']
#
#  weight_scaling_conv_21 (Weight  (None, 4, 4, 512)   4194816     ['reshape_2[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_22 (Weight  (None, 4, 4, 512)   2359808     ['weight_scaling_conv_21[0][0]']
#  ScalingConv)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 512)   0           ['weight_scaling_conv_22[0][0]']
#
#  weight_scaling_conv_24 (Weight  (None, 8, 8, 512)   2359808     ['up_sampling2d_1[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_25 (Weight  (None, 8, 8, 512)   2359808     ['weight_scaling_conv_24[0][0]']
#  ScalingConv)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 512)  0          ['weight_scaling_conv_25[0][0]']
#
#  weight_scaling_conv_30 (Weight  (None, 16, 16, 512)  2359808    ['up_sampling2d_2[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_31 (Weight  (None, 16, 16, 512)  2359808    ['weight_scaling_conv_30[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_26 (Weight  multiple            1539        ['up_sampling2d_2[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_32 (Weight  (None, 16, 16, 3)   1539        ['weight_scaling_conv_31[0][0]']
#  ScalingConv)
#
#  weighted_sum_4 (WeightedSum)   (None, 16, 16, 3)    1           ['weight_scaling_conv_26[1][0]',
#                                                                   'weight_scaling_conv_32[0][0]']
#
# ==================================================================================================
# Total params: 20,199,431
# Trainable params: 20,199,430
# Non-trainable params: 1
# __________________________________________________________________________________________________
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 16, 16, 3)]  0           []
#
#  weight_scaling_conv_33 (Weight  (None, 16, 16, 512)  2048       ['input_18[0][0]']
#  ScalingConv)
#
#  weight_scaling_conv_34 (Weight  (None, 16, 16, 512)  2359808    ['weight_scaling_conv_33[2][0]']
#  ScalingConv)
#
#  average_pooling2d_4 (AveragePo  (None, 8, 8, 3)     0           ['input_18[0][0]']
#  oling2D)
#
#  weight_scaling_conv_35 (Weight  (None, 16, 16, 512)  2359808    ['weight_scaling_conv_34[2][0]']
#  ScalingConv)
#
#  weight_scaling_conv_27 (Weight  (None, 8, 8, 512)   2048        ['average_pooling2d_4[1][0]']
#  ScalingConv)
#
#  average_pooling2d_5 (AveragePo  (None, 8, 8, 512)   0           ['weight_scaling_conv_35[2][0]']
#  oling2D)
#
#  weighted_sum_5 (WeightedSum)   (None, 8, 8, 512)    1           ['weight_scaling_conv_27[4][0]',
#                                                                   'average_pooling2d_5[2][0]']
#
#  weight_scaling_conv_28 (Weight  (None, 8, 8, 512)   2359808     ['weighted_sum_5[1][0]']
#  ScalingConv)
#
#  weight_scaling_conv_29 (Weight  (None, 8, 8, 512)   2359808     ['weight_scaling_conv_28[6][0]']
#  ScalingConv)
#
#  average_pooling2d_3 (AveragePo  (None, 4, 4, 512)   0           ['weight_scaling_conv_29[6][0]']
#  oling2D)
#
#  minibatch_stdev_2 (MinibatchSt  (None, 4, 4, 513)   0           ['average_pooling2d_3[6][0]']
#  dev)
#
#  weight_scaling_conv_19 (Weight  (None, 4, 4, 512)   2364416     ['minibatch_stdev_2[9][0]']
#  ScalingConv)
#
#  weight_scaling_conv_20 (Weight  (None, 1, 1, 512)   4194816     ['weight_scaling_conv_19[9][0]']
#  ScalingConv)
#
#  flatten_2 (Flatten)            (None, 512)          0           ['weight_scaling_conv_20[9][0]']
#
#  weight_scaling_dense_4 (Weight  (None, 1)           513         ['flatten_2[9][0]']
#  ScalingDense)
#
# ==================================================================================================
# Total params: 16,003,074
# Trainable params: 16,003,073
# Non-trainable params: 1
# __________________________________________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 109s 101ms/step - d_loss: -2.4177 - g_loss: 3.1770
# Epoch 2/50
# 1000/1000 [==============================] - 102s 102ms/step - d_loss: -4.4508 - g_loss: 5.9703
# Epoch 3/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -5.3073 - g_loss: 6.6362
# Epoch 4/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -5.5423 - g_loss: 7.0331
# Epoch 5/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -5.5019 - g_loss: 7.2474
# Epoch 6/50
# 1000/1000 [==============================] - 102s 102ms/step - d_loss: -5.4235 - g_loss: 7.1101
# Epoch 7/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -5.3680 - g_loss: 7.0947
# Epoch 8/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -5.0559 - g_loss: 6.7430
# Epoch 9/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -4.7641 - g_loss: 6.2783
# Epoch 10/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -4.3948 - g_loss: 5.7385
# Epoch 11/50
# 1000/1000 [==============================] - 102s 102ms/step - d_loss: -4.1105 - g_loss: 5.4044
# Epoch 12/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -3.8834 - g_loss: 5.1144
# Epoch 13/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -3.6199 - g_loss: 4.7676
# Epoch 14/50
# 1000/1000 [==============================] - 105s 105ms/step - d_loss: -3.3641 - g_loss: 4.4214
# Epoch 15/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -3.0618 - g_loss: 4.1099
# Epoch 16/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -2.8170 - g_loss: 3.8401
# Epoch 17/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -2.5506 - g_loss: 3.4819
# Epoch 18/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -2.2146 - g_loss: 3.1062
# Epoch 19/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -1.9998 - g_loss: 2.8219
# Epoch 20/50
# 1000/1000 [==============================] - 102s 102ms/step - d_loss: -1.7300 - g_loss: 2.5297
# Epoch 21/50
# 1000/1000 [==============================] - 102s 102ms/step - d_loss: -1.5849 - g_loss: 2.2757
# Epoch 22/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -1.3900 - g_loss: 2.0971
# Epoch 23/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -1.1902 - g_loss: 1.8265
# Epoch 24/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -1.0239 - g_loss: 1.6258
# Epoch 25/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.8782 - g_loss: 1.3994
# Epoch 26/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.7744 - g_loss: 1.2740
# Epoch 27/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.6295 - g_loss: 1.1254
# Epoch 28/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.5354 - g_loss: 0.9706
# Epoch 29/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.4455 - g_loss: 0.8425
# Epoch 30/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.3515 - g_loss: 0.7294
# Epoch 31/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.2651 - g_loss: 0.6573
# Epoch 32/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.2396 - g_loss: 0.5829
# Epoch 33/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.1907 - g_loss: 0.4800
# Epoch 34/50
# 1000/1000 [==============================] - 102s 101ms/step - d_loss: -0.1502 - g_loss: 0.4638
# Epoch 35/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1207 - g_loss: 0.4004
# Epoch 36/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1188 - g_loss: 0.3749
# Epoch 37/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1038 - g_loss: 0.3728
# Epoch 38/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1063 - g_loss: 0.3292
# Epoch 39/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1334 - g_loss: 0.3800
# Epoch 40/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1542 - g_loss: 0.4120
# Epoch 41/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1546 - g_loss: 0.4419
# Epoch 42/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.1785 - g_loss: 0.4625
# Epoch 43/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.2139 - g_loss: 0.4729
# Epoch 44/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.2566 - g_loss: 0.4806
# Epoch 45/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.2554 - g_loss: 0.5229
# Epoch 46/50
# 1000/1000 [==============================] - 107s 106ms/step - d_loss: -0.3030 - g_loss: 0.5806
# Epoch 47/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.3147 - g_loss: 0.5863
# Epoch 48/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.3502 - g_loss: 0.6998
# Epoch 49/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.3776 - g_loss: 0.6772
# Epoch 50/50
# 1000/1000 [==============================] - 103s 102ms/step - d_loss: -0.4021 - g_loss: 0.7348
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 512)]             0
#
#  pixel_normalization_152 (Pi  (None, 512)              0
#  xelNormalization)
#
#  weight_scaling_dense_5 (Wei  (None, 8192)             4202496
#  ghtScalingDense)
#
#  reshape_2 (Reshape)         (None, 4, 4, 512)         0
#
#  weight_scaling_conv_21 (Wei  (None, 4, 4, 512)        4194816
#  ghtScalingConv)
#
#  weight_scaling_conv_22 (Wei  (None, 4, 4, 512)        2359808
#  ghtScalingConv)
#
#  up_sampling2d_1 (UpSampling  (None, 8, 8, 512)        0
#  2D)
#
#  weight_scaling_conv_24 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_25 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  up_sampling2d_2 (UpSampling  (None, 16, 16, 512)      0
#  2D)
#
#  weight_scaling_conv_30 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_31 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_32 (Wei  (None, 16, 16, 3)        1539
#  ghtScalingConv)
#
# =================================================================
# Total params: 20,197,891
# Trainable params: 20,197,891
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 16, 16, 3)]       0
#
#  weight_scaling_conv_33 (Wei  (None, 16, 16, 512)      2048
#  ghtScalingConv)
#
#  weight_scaling_conv_34 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_35 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  average_pooling2d_5 (Averag  (None, 8, 8, 512)        0
#  ePooling2D)
#
#  weight_scaling_conv_28 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_29 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  average_pooling2d_3 (Averag  (None, 4, 4, 512)        0
#  ePooling2D)
#
#  minibatch_stdev_2 (Minibatc  (None, 4, 4, 513)        0
#  hStdev)
#
#  weight_scaling_conv_19 (Wei  (None, 4, 4, 512)        2364416
#  ghtScalingConv)
#
#  weight_scaling_conv_20 (Wei  (None, 1, 1, 512)        4194816
#  ghtScalingConv)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  weight_scaling_dense_4 (Wei  (None, 1)                513
#  ghtScalingDense)
#
# =================================================================
# Total params: 16,001,025
# Trainable params: 16,001,025
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 104s 100ms/step - d_loss: -0.3974 - g_loss: 0.7767
# Epoch 2/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4198 - g_loss: 0.6369
# Epoch 3/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4124 - g_loss: 0.6912
# Epoch 4/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4292 - g_loss: 0.6453
# Epoch 5/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4292 - g_loss: 0.6634
# Epoch 6/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4231 - g_loss: 0.6857
# Epoch 7/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4404 - g_loss: 0.6414
# Epoch 8/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4275 - g_loss: 0.6678
# Epoch 9/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.3997 - g_loss: 0.6156
# Epoch 10/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4306 - g_loss: 0.6323
# Epoch 11/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4108 - g_loss: 0.6380
# Epoch 12/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4123 - g_loss: 0.5897
# Epoch 13/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4004 - g_loss: 0.6037
# Epoch 14/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4148 - g_loss: 0.5789
# Epoch 15/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.3955 - g_loss: 0.6197
# Epoch 16/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4294 - g_loss: 0.6229
# Epoch 17/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4217 - g_loss: 0.6268
# Epoch 18/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4190 - g_loss: 0.5823
# Epoch 19/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4263 - g_loss: 0.6229
# Epoch 20/50
# 1000/1000 [==============================] - 101s 101ms/step - d_loss: -0.4135 - g_loss: 0.6092
# Epoch 21/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4098 - g_loss: 0.6148
# Epoch 22/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4293 - g_loss: 0.6289
# Epoch 23/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4317 - g_loss: 0.5986
# Epoch 24/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4243 - g_loss: 0.5810
# Epoch 25/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4208 - g_loss: 0.6170
# Epoch 26/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4179 - g_loss: 0.6435
# Epoch 27/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4289 - g_loss: 0.5748
# Epoch 28/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4311 - g_loss: 0.5524
# Epoch 29/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4562 - g_loss: 0.5741
# Epoch 30/50
# 1000/1000 [==============================] - 101s 100ms/step - d_loss: -0.4427 - g_loss: 0.6495
# Epoch 31/50
# ...
#  weight_scaling_conv_20 (Weight  (None, 1, 1, 512)   4194816     ['weight_scaling_conv_19[13][0]']
#  ScalingConv)
#
#  flatten_2 (Flatten)            (None, 512)          0           ['weight_scaling_conv_20[13][0]']
#
#  weight_scaling_dense_4 (Weight  (None, 1)           513         ['flatten_2[13][0]']
#  ScalingDense)
#
# ==================================================================================================
# Total params: 20,722,690
# Trainable params: 20,722,689
# Non-trainable params: 1
# __________________________________________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 256s 247ms/step - d_loss: -3.0968 - g_loss: 5.4397
# Epoch 2/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -5.9475 - g_loss: 9.1898
# Epoch 3/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -7.3389 - g_loss: 10.3387
# Epoch 4/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -8.2081 - g_loss: 11.1838
# Epoch 5/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -8.1716 - g_loss: 10.9522
# Epoch 6/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -7.8260 - g_loss: 10.6595
# Epoch 7/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -7.5468 - g_loss: 10.2170
# Epoch 8/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -7.1606 - g_loss: 9.6974
# Epoch 9/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -6.5956 - g_loss: 8.9710
# Epoch 10/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -6.3341 - g_loss: 8.7087
# Epoch 11/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -6.0003 - g_loss: 8.4174
# Epoch 12/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -5.2222 - g_loss: 7.3990
# Epoch 13/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -5.0301 - g_loss: 7.1291
# Epoch 14/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -4.4552 - g_loss: 6.3306
# Epoch 15/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -4.0199 - g_loss: 5.8482
# Epoch 16/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -3.5142 - g_loss: 5.1190
# Epoch 17/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -3.4558 - g_loss: 5.0351
# Epoch 18/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -2.8825 - g_loss: 4.3998
# Epoch 19/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -2.4389 - g_loss: 3.8576
# Epoch 20/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -2.1146 - g_loss: 3.4854
# Epoch 21/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -1.9900 - g_loss: 3.1580
# Epoch 22/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -1.8739 - g_loss: 2.9512
# Epoch 23/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -1.4579 - g_loss: 2.5032
# Epoch 24/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -1.2792 - g_loss: 2.1733
# Epoch 25/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -1.1322 - g_loss: 1.9697
# Epoch 26/50
# 1000/1000 [==============================] - 247s 246ms/step - d_loss: -0.9853 - g_loss: 1.7076
# Epoch 27/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.8327 - g_loss: 1.4844
# Epoch 28/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.6902 - g_loss: 1.2858
# Epoch 29/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.5633 - g_loss: 1.0839
# Epoch 30/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.4114 - g_loss: 0.9287
# Epoch 31/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.3405 - g_loss: 0.8081
# Epoch 32/50
# 1000/1000 [==============================] - 253s 252ms/step - d_loss: -0.2994 - g_loss: 0.7328
# Epoch 33/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2669 - g_loss: 0.7106
# Epoch 34/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2415 - g_loss: 0.6665
# Epoch 35/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2046 - g_loss: 0.6114
# Epoch 36/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2158 - g_loss: 0.6176
# Epoch 37/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2314 - g_loss: 0.6227
# Epoch 38/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2522 - g_loss: 0.6200
# Epoch 39/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.2478 - g_loss: 0.6314
# Epoch 40/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.2908 - g_loss: 0.6706
# Epoch 41/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.3499 - g_loss: 0.6912
# Epoch 42/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.3769 - g_loss: 0.7658
# Epoch 43/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.3921 - g_loss: 0.7674
# Epoch 44/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.4074 - g_loss: 0.8289
# Epoch 45/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.4135 - g_loss: 0.8577
# Epoch 46/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.4354 - g_loss: 0.8033
# Epoch 47/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.4809 - g_loss: 0.9390
# Epoch 48/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.5228 - g_loss: 0.9277
# Epoch 49/50
# 1000/1000 [==============================] - 248s 247ms/step - d_loss: -0.5247 - g_loss: 0.9637
# Epoch 50/50
# 1000/1000 [==============================] - 247s 247ms/step - d_loss: -0.5639 - g_loss: 0.9565
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 512)]             0
#
#  pixel_normalization_152 (Pi  (None, 512)              0
#  xelNormalization)
#
#  weight_scaling_dense_5 (Wei  (None, 8192)             4202496
#  ghtScalingDense)
#
#  reshape_2 (Reshape)         (None, 4, 4, 512)         0
#
#  weight_scaling_conv_21 (Wei  (None, 4, 4, 512)        4194816
#  ghtScalingConv)
#
#  weight_scaling_conv_22 (Wei  (None, 4, 4, 512)        2359808
#  ghtScalingConv)
#
#  up_sampling2d_1 (UpSampling  (None, 8, 8, 512)        0
#  2D)
#
#  weight_scaling_conv_24 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_25 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  up_sampling2d_2 (UpSampling  (None, 16, 16, 512)      0
#  2D)
#
#  weight_scaling_conv_30 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_31 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  up_sampling2d_3 (UpSampling  (None, 32, 32, 512)      0
#  2D)
#
#  weight_scaling_conv_36 (Wei  (None, 32, 32, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_37 (Wei  (None, 32, 32, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_38 (Wei  (None, 32, 32, 3)        1539
#  ghtScalingConv)
#
# =================================================================
# Total params: 24,917,507
# Trainable params: 24,917,507
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  weight_scaling_conv_39 (Wei  (None, 32, 32, 512)      2048
#  ghtScalingConv)
#
#  weight_scaling_conv_40 (Wei  (None, 32, 32, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_41 (Wei  (None, 32, 32, 512)      2359808
#  ghtScalingConv)
#
#  average_pooling2d_7 (Averag  (None, 16, 16, 512)      0
#  ePooling2D)
#
#  weight_scaling_conv_34 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_35 (Wei  (None, 16, 16, 512)      2359808
#  ghtScalingConv)
#
#  average_pooling2d_5 (Averag  (None, 8, 8, 512)        0
#  ePooling2D)
#
#  weight_scaling_conv_28 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  weight_scaling_conv_29 (Wei  (None, 8, 8, 512)        2359808
#  ghtScalingConv)
#
#  average_pooling2d_3 (Averag  (None, 4, 4, 512)        0
#  ePooling2D)
#
#  minibatch_stdev_2 (Minibatc  (None, 4, 4, 513)        0
#  hStdev)
#
#  weight_scaling_conv_19 (Wei  (None, 4, 4, 512)        2364416
#  ghtScalingConv)
#
#  weight_scaling_conv_20 (Wei  (None, 1, 1, 512)        4194816
#  ghtScalingConv)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  weight_scaling_dense_4 (Wei  (None, 1)                513
#  ghtScalingDense)
#
# =================================================================
# Total params: 20,720,641
# Trainable params: 20,720,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 247s 242ms/step - d_loss: -0.5947 - g_loss: 1.0694
# Epoch 2/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.5924 - g_loss: 0.9959
# Epoch 3/50
# 1000/1000 [==============================] - 243s 242ms/step - d_loss: -0.5941 - g_loss: 0.9944
# Epoch 4/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.5979 - g_loss: 0.9836
# Epoch 5/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.5972 - g_loss: 0.9655
# Epoch 6/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6089 - g_loss: 1.0328
# Epoch 7/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6244 - g_loss: 1.1291
# Epoch 8/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6306 - g_loss: 1.0149
# Epoch 9/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6395 - g_loss: 1.0245
# Epoch 10/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6153 - g_loss: 1.0318
# Epoch 11/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6336 - g_loss: 1.0453
# Epoch 12/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6361 - g_loss: 1.0432
# Epoch 13/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6684 - g_loss: 1.0054
# Epoch 14/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6418 - g_loss: 1.0161
# Epoch 15/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6534 - g_loss: 1.0385
# Epoch 16/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6584 - g_loss: 0.9851
# Epoch 17/50
# 1000/1000 [==============================] - 244s 243ms/step - d_loss: -0.6401 - g_loss: 0.9921
# Epoch 18/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6668 - g_loss: 1.1025
# Epoch 19/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6732 - g_loss: 1.0633
# Epoch 20/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6853 - g_loss: 1.0557
# Epoch 21/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.7022 - g_loss: 1.1043
# Epoch 22/50
# 1000/1000 [==============================] - 243s 243ms/step - d_loss: -0.6900 - g_loss: 1.0548
# Epoch 23/50
# 1000/1000 [==============================] - 243s 242ms/step - d_loss: -0.7068 - g_loss: 1.0224
# Epoch 24/50
#   61/1000 [>.............................] - ETA: 3:46 - d_loss: -0.7064 - g_loss: 0.9758

# %%
pgan.generator.save_weights('pggan_generator_128.h5')
pgan.discriminator.save_weights('pggan_discriminator_128.h5')
